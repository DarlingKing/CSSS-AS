# %% [markdown]
# ## Part 3: Communities for the Zachary Karate Club Network

# %% [markdown]
# _Exercise: Zachary's karate club_: In this exercise, we will work on Zarachy's karate club graph (refer to the Introduction of Chapter 9). The dataset is available in NetworkX, by calling the function [karate_club_graph](https://networkx.org/documentation/stable/auto_examples/graph/plot_karate_club.html).

# %% [markdown]
# > 1. Visualize the graph using [netwulf](https://netwulf.readthedocs.io/en/latest/). Set the color of each node based on the club split (the information is stored as a node attribute). My version of the visualization is below.
# <img src="https://github.com/lalessan/comsocsci2021/raw/master/files/karate.png" alt="Drawing" style="width: 200px;"/>

# %%
import networkx as nx
import netwulf as nw
from networkx.algorithms import community
import community as community_louvain

G = nx.karate_club_graph()

C = community_louvain.best_partition(G) #使用Louvain算法进行分区
nx.set_node_attributes(G, C, 'louvain')#设置节点属性
G_louvain = nw.get_filtered_network(G,node_group_key='louvain')

nw.visualize(G_louvain)
# Out:
# ({'xlim': [0, 760],
#   'ylim': [0, 760],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 2.3748324489939208,
#   'links': [{'source': 0,
#     'target': 1,
#     'width': 4.7496648979878415,
#     'weight': 1},
#    {'source': 0, 'target': 2, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 3, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 4, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 5, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 6, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 7, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 8, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 10, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 11, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 12, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 13, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 17, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 19, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 21, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 0, 'target': 31, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 2, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 3, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 7, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 13, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 17, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 19, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 21, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 1, 'target': 30, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 3, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 7, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 8, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 9, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 13, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 27, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 28, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 2, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 3, 'target': 7, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 3, 'target': 12, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 3, 'target': 13, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 4, 'target': 6, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 4, 'target': 10, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 5, 'target': 6, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 5, 'target': 10, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 5, 'target': 16, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 6, 'target': 16, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 8, 'target': 30, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 8, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 8, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 9, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 13, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 14, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 14, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 15, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 15, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 18, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 18, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 19, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 20, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 20, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 22, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 22, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 23, 'target': 25, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 23, 'target': 27, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 23, 'target': 29, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 23, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 23, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 24, 'target': 25, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 24, 'target': 27, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 24, 'target': 31, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 25, 'target': 31, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 26, 'target': 29, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 26, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 27, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 28, 'target': 31, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 28, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 29, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 29, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 30, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 30, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 31, 'target': 32, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 31, 'target': 33, 'width': 4.7496648979878415, 'weight': 1},
#    {'source': 32, 'target': 33, 'width': 4.7496648979878415, 'weight': 1}],
#   'nodes': [{'id': 0,
#     'x': 343.5841020150304,
#     'y': 362.2611079376407,
#     'x_canvas': 243.45258559705326,
#     'y_canvas': 313.4850991045762,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 1,
#     'x': 381.54058223642795,
#     'y': 317.45617691739,
#     'x_canvas': 385.7766671343975,
#     'y_canvas': 145.48162200117554,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 2,
#     'x': 369.83496423244736,
#     'y': 370.90618276050174,
#     'x_canvas': 341.8845221956169,
#     'y_canvas': 345.9012327083367,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 3,
#     'x': 340.50690266936033,
#     'y': 322.9522093317918,
#     'x_canvas': 231.91411922648308,
#     'y_canvas': 166.0899018236612,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 4,
#     'x': 303.87806697651666,
#     'y': 366.79503701252185,
#     'x_canvas': 94.56825977486301,
#     'y_canvas': 330.4858138066245,
#     'radius': 18.748324489939208,
#     'color': '#8afa97'},
#    {'id': 5,
#     'x': 318.0817604858262,
#     'y': 404.96964461793766,
#     'x_canvas': 147.8273507484987,
#     'y_canvas': 473.62779993911204,
#     'radius': 18.748324489939208,
#     'color': '#8afa97'},
#    {'id': 6,
#     'x': 300.1833506686376,
#     'y': 389.23275948555397,
#     'x_canvas': 80.71431172718576,
#     'y_canvas': 414.61975415454594,
#     'radius': 18.748324489939208,
#     'color': '#8afa97'},
#    {'id': 7,
#     'x': 351.85245454440064,
#     'y': 340.103241767344,
#     'x_canvas': 274.45613684062187,
#     'y_canvas': 230.40052611150236,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 8,
#     'x': 397.20951413834825,
#     'y': 365.8140331435637,
#     'x_canvas': 444.52991107598996,
#     'y_canvas': 326.80737803440184,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 9,
#     'x': 388.5909755213959,
#     'y': 385.9556110594041,
#     'x_canvas': 412.2132793520509,
#     'y_canvas': 402.33154573551565,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 10,
#     'x': 320.9645723898259,
#     'y': 383.9211052946949,
#     'x_canvas': 158.63692935242784,
#     'y_canvas': 394.70283088483166,
#     'radius': 18.748324489939208,
#     'color': '#8afa97'},
#    {'id': 11,
#     'x': 323.1520441154876,
#     'y': 358.1329482594563,
#     'x_canvas': 166.8392152974825,
#     'y_canvas': 298.00588366599936,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 12,
#     'x': 322.17898521422813,
#     'y': 335.3305900448736,
#     'x_canvas': 163.19057049175535,
#     'y_canvas': 212.5046814774339,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 13,
#     'x': 373.9712338520634,
#     'y': 346.97585561378884,
#     'x_canvas': 357.39414719690467,
#     'y_canvas': 256.1705250089417,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 14,
#     'x': 426.294857510131,
#     'y': 369.2288924565809,
#     'x_canvas': 553.590202163087,
#     'y_canvas': 339.6119561319895,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 15,
#     'x': 427.5200721306434,
#     'y': 410.96140512061135,
#     'x_canvas': 558.184346418124,
#     'y_canvas': 496.09489397313746,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 16,
#     'x': 295.24744547284195,
#     'y': 414.71469658945756,
#     'x_canvas': 62.20632127471504,
#     'y_canvas': 510.16847924578747,
#     'radius': 18.748324489939208,
#     'color': '#8afa97'},
#    {'id': 17,
#     'x': 355.47268601622477,
#     'y': 318.43611645142454,
#     'x_canvas': 288.03079171311174,
#     'y_canvas': 149.1560668740956,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 18,
#     'x': 447.52356162387787,
#     'y': 390.96139853024886,
#     'x_canvas': 633.1907288081736,
#     'y_canvas': 421.1015713017298,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 19,
#     'x': 388.2636724654528,
#     'y': 349.57815486708074,
#     'x_canvas': 410.9860025721771,
#     'y_canvas': 265.92827517307046,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 20,
#     'x': 446.86909554411807,
#     'y': 378.04390045976373,
#     'x_canvas': 630.7367003219745,
#     'y_canvas': 372.66528221700605,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 21,
#     'x': 362.351077108166,
#     'y': 329.65137952249114,
#     'x_canvas': 313.822453345196,
#     'y_canvas': 191.20954513337324,
#     'radius': 18.748324489939208,
#     'color': '#79aaa0'},
#    {'id': 22,
#     'x': 439.16929296563853,
#     'y': 367.55752107029576,
#     'x_canvas': 601.8650208720137,
#     'y_canvas': 333.34487351333473,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 23,
#     'x': 421.4924445865025,
#     'y': 434.0418050591325,
#     'x_canvas': 535.5827629977139,
#     'y_canvas': 582.6386594541309,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 24,
#     'x': 374.2958505946652,
#     'y': 451.1750130244856,
#     'x_canvas': 358.61135120193785,
#     'y_canvas': 646.8824479517409,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 25,
#     'x': 396.4846111201327,
#     'y': 455.14804786982614,
#     'x_canvas': 441.8117676741415,
#     'y_canvas': 661.7799972497971,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 26,
#     'x': 450.1196120785287,
#     'y': 406.65652252367437,
#     'x_canvas': 642.9250480713833,
#     'y_canvas': 479.95302680944405,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 27,
#     'x': 394.1407265586381,
#     'y': 421.12594737333643,
#     'x_canvas': 433.0229860089696,
#     'y_canvas': 534.2085212622949,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 28,
#     'x': 377.64829248807735,
#     'y': 400.955377135959,
#     'x_canvas': 371.1818848922094,
#     'y_canvas': 458.57564207080236,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 29,
#     'x': 444.6345469315764,
#     'y': 423.68675193863584,
#     'x_canvas': 622.3578918266796,
#     'y_canvas': 543.8106802514051,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 30,
#     'x': 418.4115860904289,
#     'y': 345.4189152978348,
#     'x_canvas': 524.0305760393192,
#     'y_canvas': 250.33252055794696,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 31,
#     'x': 377.1851958432214,
#     'y': 420.76997330216807,
#     'x_canvas': 369.44542765861684,
#     'y_canvas': 532.873737783041,
#     'radius': 18.748324489939208,
#     'color': '#8251db'},
#    {'id': 32,
#     'x': 427.8860918664301,
#     'y': 390.7747202718181,
#     'x_canvas': 559.556797773374,
#     'y_canvas': 420.4015903888744,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'},
#    {'id': 33,
#     'x': 412.6406701461106,
#     'y': 391.0316672391168,
#     'x_canvas': 502.39157509367055,
#     'y_canvas': 421.3650554127987,
#     'radius': 18.748324489939208,
#     'color': '#723d3b'}]},
#  {'zoom': 2.3748324489939208,
#   'node_charge': -45,
#   'node_gravity': 0.1,
#   'link_distance': 15,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': False,
#   'freeze_nodes': False,
#   'node_fill_color': '#79aaa0',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 5,
#   'node_stroke_width': 1,
#   'node_size_variation': 0.5,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})

# %% [markdown]
# > 2. Write a function to compute the __modularity__ of a graph partitioning (use **equation 9.12** in the book). The function should take a networkX Graph and a partitioning as inputs and return the modularity.
# $$ M = \sum\limits_{c = 1}^{n_c } {\left[ {\frac{{L_c }}{L} - \left( {\frac{{k_c }}{{2L}}} \right)^2 } \right]}  \hspace{20 mm} (9 . 12) $$

# %% [markdown]
# [Note]
# + $M$:Modularity
# + $n_c$:the number of communities 社区数
# + $L_c$:the total number of links within the community $C_c$该社区内的链接总数
# + $k_c$:the total degree of the nodes in community $C_c$该社区的节点度数

# %%
import math

def ModularityLV(G,C):
#print(C)
    count=list(set([i for i in C.values()]))
    #print(count)
    #print(len(count))

    n_c=len(count)
    L=G.number_of_edges()
    M=0

    for c in range(0,n_c):
        #print('leavel of subgraphy:',c)
        sub=[]
        L_c=0
        k_c=0
        #i=0
        for n in G.nodes:
            if G.nodes[n]["louvain"]==c:
                #i+=1
                k_c+=G.degree(n)
                sub.append(n)    
        L_c=G.subgraph(sub).number_of_edges()
        #print(L_c)
        #print(k_c)
        #print('number of nodes:',i)
        M+=(L_c/L)-pow((k_c/(2*L)),2)

    print(M)
    return

# %% [markdown]
# > 3. Explain in your own words the concept of _modularity_.

# %% [markdown]
# <font color=blue>
#     Modularity can be used to determine how good the community segmentation results are. The larger the modularity, the better the community classification, and the best clustering result is when the result is between 0.3 and 0.7.
# </font>

# %% [markdown]
# > 4. Compute the modularity of the Karate club split partitioning using the function you just wrote. Note: the Karate club split partitioning is avilable as a [node attribute](https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.classes.function.get_node_attributes.html), called _"club"_.

# %%
ModularityLV(G,C)
# community_louvain.modularity(C, G_louvain)
# Out:
# 0.4188034188034188

# %% [markdown]
# > 5. We will now perform a small randomization experiment to assess if the modularity you just computed is statitically different from $0$. To do so, we will implement a [configuration model](https://en.wikipedia.org/wiki/Configuration_model). In short, we will create a new network, such that each node has the same degree as in the original network, but different connections. Here is how the algorithm works.
# >       * __a.__ Create an identical copy of your original network.
# >       * __b.__ Consider the list of network edges. Create two lists: the list of source nodes and target nodes. (e.g. edges = [(1,2),(3,4)], sources = [1,3], targets = [2,4])
# >       * __c.__ Concatenate the list of source nodes and target nodes into a unique list (e.g. [1,3,2,4]). This is the list of _stubs_ (see the [Wikipedia page](https://en.wikipedia.org/wiki/Configuration_model) for the definition of stub).
# >       * __d.__ Shuffle the list of stubs. Build a set of edges (tuples), by connecting each element in the list of shuffled stubs with the following element. (e.g. [4,1,2,3] --> [(4,1),(2,3)])
# >       * __e.__ Remove all the original network edges from your network. Add all the new _shuffled_ edges you created in step __d.__

# %%
import matplotlib.pyplot as plt

#产生degree序列
sequence=[]
for n in G.nodes:
    sequence.append(G.degree(n))
#print(sequence)

G_2 = nx.configuration_model(sequence)

pos = nx.circular_layout(G_2)

nx.draw_networkx(G_2,pos)
plt.show()
nx.draw_networkx(G,pos)
plt.show()

# %% [markdown]
# > 6. Is the degree of the nodes in your original and the configuration model network the same? Why?
#
# __Note 1:__ With this algorithm you may obtain some self-loops. Note that [a self-loop should add two to the degree](https://en.wikipedia.org/wiki/Loop_(graph_theory%29#:~:text=For%20an%20undirected%20graph%2C%20the,adds%20two%20to%20the%20degree.&text=In%20other%20words%2C%20a%20vertex,not%20one%2C%20to%20the%20degree.).
#
# __Note 2:__ With this algorithm, you could also obtain repeated edges between the same two nodes. Only NetworkX [MultiGraph](https://networkx.org/documentation/stable/reference/classes/multigraph.html) allow for repeated edges, while regular [Graph](https://networkx.org/documentation/stable/reference/classes/graph.html?highlight=graph%20undirected#networkx.Graph) do not, meaning you will not be able to account for multi-edges when you have a regular Graph. (_Optional_: if you want to implement a configuration model without self-loops and multi-edges, you can try out the [double_edge_swap](https://networkx.org/documentation/stable//reference/algorithms/generated/networkx.algorithms.swap.double_edge_swap.html) algorithm)

# %%
DG1=[]
DG2=[]

for n in G.nodes:
    DG1.append(G.degree(n))
for n in G_2.nodes:
    DG2.append(G_2.degree(n))

if DG1 == DG2:
    print('YES')
else:
    print('NO')
        
print('Degree of nodes of Graph 1:',DG1)
print('Degree of nodes of Graph 2:',DG2)
# Out:
# YES
# Degree of nodes of Graph 1: [16, 9, 10, 6, 3, 4, 4, 4, 5, 2, 3, 1, 2, 5, 2, 2, 2, 2, 2, 3, 2, 2, 2, 5, 3, 3, 2, 4, 3, 4, 4, 6, 12, 17]
# Degree of nodes of Graph 2: [16, 9, 10, 6, 3, 4, 4, 4, 5, 2, 3, 1, 2, 5, 2, 2, 2, 2, 2, 3, 2, 2, 2, 5, 3, 3, 2, 4, 3, 4, 4, 6, 12, 17]

# %% [markdown]
# <font color=blue> Because the configuration model is a method for generating random networks from a given degree sequence.

# %% [markdown]
# > 7. Create $1000$ randomized version of the Karate Club network using the algorithm you wrote in step 5. For each of them, compute the modularity of the "club" split and store it in a list.

# %%
clublist=[]
sum=0
for n in range(0,1000):
    #print(n)
    G_N = nx.configuration_model(sequence)
    C_N = community_louvain.best_partition(G_N) #使用Louvain算法进行分区
    nx.set_node_attributes(G_N, C_N, 'louvain')#设置节点属性
    G_N = nw.get_filtered_network(G,node_group_key='louvain')
    M_N=community_louvain.modularity(C_N, G_N)
    clublist.append(M_N)
    sum+=M_N
print(clublist)
# Out:
# [-0.0839086127547666, 0.01512163050624589, -0.014546351084812649, -0.05251479289940829, 0.012491781722550985, -0.0541584483892176, -0.033284023668639064, -0.053500986193293895, -0.03385930309007229, -0.043885601577909245, -0.05407626561472713, -0.1253287310979619, -0.08423734385272846, -0.032708744247205795, 0.037475345167652864, -0.03196909927679159, -0.06426692965154504, -0.0304898093359632, -0.05711702827087442, -0.004355687047994758, -0.09089414858645627, 0.013642340565417459, -0.1205621301775148, -0.051364234056541745, -0.10198882314266931, -0.08801775147928995, -0.017669296515450385, 0.0212853385930309, 0.00928665351742276, -0.036900065746219596, -0.10494740302432613, -0.062294543063773855, 0.005752794214332637, -0.035420775805391214, -0.02547666009204471, -0.03813280736357658, -0.09081196581196585, -0.07996383957922422, -0.048076923076923066, -0.011587771203155815, -0.04421433267587113, -0.05596646942800787, -0.0571170282708744, -0.05539119000657461, -0.13173898750821822, -0.042077580539119044, -0.08809993425378042, -0.04939184746877055, -0.024408284023668646, -0.053336620644312924, 0.02490138067061142, -0.08982577251808026, -0.060239973701512156, -0.09105851413543722, 0.05259697567389876, -0.06278763971071663, -0.00583497698882314, -0.020134779750164356, -0.07519723865877712, -0.07610124917817229, -0.027202498356344522, -0.016847468770545715, -0.025476660092044703, -0.06615713346482578, -0.041009204470742924, 0.039201183431952655, 0.002958579881656806, -0.0332018408941486, -0.01980604865220252, -0.020381328073635744, -0.06566403681788299, -0.03640696909927679, 0.003616042077580546, -0.07642998027613414, -0.03525641025641026, -0.027284681130835018, -0.08752465483234714, -0.11702827087442473, -0.06747205785667326, -0.026216305062458936, -0.01701183431952664, 0.015861275476660087, 0.04183103221564761, -0.06574621959237344, -0.06467784352399739, -0.026545036160420817, -0.05358316896778436, -0.050049309664694286, 0.025065746219592393, -0.03476331360946748, -0.015368178829717275, -0.05144641683103223, -0.06015779092702171, -0.0428172255095332, -0.0835798816568047, -0.015285996055226812, -0.04092702169625247, -0.0759368836291913, -0.03854372123602893, -0.050624589086127554, -0.05210387902695593, -0.06722550953320185, -0.07667652859960554, -0.01610782380013149, -0.035174227481919826, -0.047419460880999346, 0.05169296515450359, -0.032297830374753464, -0.037475345167652864, -0.012163050624589104, -0.025969756738987514, -0.07601906640368176, -0.0589250493096647, 0.04659763313609468, 0.012080867850098626, -0.08793556870479949, 0.03739316239316241, -0.04018737672583827, -0.07486850756081524, -0.0002465483234713982, -0.07733399079552926, -0.06870479947403027, -0.023257725180802102, -0.009040105193951348, -0.009368836291913235, -0.045940170940170985, -0.03607823800131491, -0.011834319526627234, -0.14020381328073633, -0.05309007232084152, -0.039694280078895465, -0.014381985535831688, -0.0970578566732413, -0.08341551610782379, 0.0012327416173569718, 0.012409598948060471, -0.037146614069691025, -0.07453977646285338, -0.06484220907297833, -0.07947074293228137, -0.06402038132807364, -0.03287310979618674, -0.031147271531886914, -0.006821170282708769, -0.02564102564102564, 0.01964168310322157, 0.012080867850098612, -0.022518080210387894, -0.09911242603550297, -0.048241288625903996, -0.004026955950032884, 0.058185404339250485, -0.05185733070348458, -0.0715811965811966, -0.05432281393819854, -0.06089743589743592, -0.02210716633793557, -0.04125575279421437, 0.009286653517422732, -0.10880999342537805, -0.04232412886259039, -0.0633629191321499, -0.06360946745562128, -0.06147271531886917, 0.059829059829059825, -0.005834976988823154, -0.013888888888888899, -0.0020545693622616885, -0.03435239973701512, 0.022024983563445115, -0.008957922419460852, -0.016190006574621968, -0.020216962524654835, -0.0636916502301118, -0.03418803418803411, -0.07832018408941487, -0.10831689677843523, -0.005999342537804077, -0.0627054569362262, -0.102646285338593, -0.10305 ...

# %% [markdown]
# > 8. Compute the average and standard deviation of the modularity for the configuration model.

# %%
ave=sum/1000
print(ave)
# Out:
# -0.03715590072320847

# %% [markdown]
# > 9. Plot the distribution of the configuration model modularity. Plot the actual modularity of the club split as a vertical line (use [axvline](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvline.html)).

# %%
y=[]
for n in range(0,1000):
    y.append(n)
    
S=community_louvain.modularity(C, G_louvain)

plt.scatter(clublist,y)
plt.axvline(S)
plt.show
#q=round(int(ModularityLV(G,C),4))

#plt.axvline(q)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# > 10. Comment on the figure. Is the club split a good partitioning? Why do you think I asked you to compare with the configuration model? What is the reason why we preserved the nodes degree?

# %% [markdown]
# + <font color=blue>It's a very good partitioning.</font>
# + <font color=blue>Because it can be clearly seen the difference of modularity between the community network and random network.</font>
# + <font color=blue></font><font color=blue>Ensure that modular differences are not influenced by node degrees, but by links - and different links make communities</font>

# %% [markdown]
# > 11.  Use [the Python Louvain-algorithm implementation](https://anaconda.org/auto/python-louvain) to find communities in this graph. Report the value of modularity found by the algorithm. Is it higher or lower than what you found above for the club split? What does this comparison reveal?

# %%
import networkx as nx
import netwulf as nw
from networkx.algorithms import community
import community as community_louvain

G = nx.karate_club_graph()

G_0=G

#D=community.greedy_modularity_communities(G_0)
GD={8:1, 14:1, 15:1, 18:1, 20:1, 22:1, 23:1, 24:1, 25:1, 26:1, 27:1, 28:1, 29:1, 30:1, 31:1, 32:1, 33:1, 1:2, 2:2, 3:2, 7:2, 9:2, 12:2, 13:2, 17:2, 21:2,0:3, 16:3, 19:3, 4:3, 5:3, 6:3, 10:3, 11:3}
nx.set_node_attributes(G_0,GD,'TestList')

G_GD = nw.get_filtered_network(G_0,node_group_key='TestList')

nw.visualize(G_GD)
# Out:
# ({'xlim': [0, 760],
#   'ylim': [0, 760],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 2.230987741879727,
#   'links': [{'source': 0,
#     'target': 1,
#     'width': 4.461975483759454,
#     'weight': 1},
#    {'source': 0, 'target': 2, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 3, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 4, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 5, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 6, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 7, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 8, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 10, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 11, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 12, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 13, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 17, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 19, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 21, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 0, 'target': 31, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 2, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 3, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 7, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 13, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 17, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 19, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 21, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 1, 'target': 30, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 3, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 7, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 8, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 9, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 13, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 27, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 28, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 2, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 3, 'target': 7, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 3, 'target': 12, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 3, 'target': 13, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 4, 'target': 6, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 4, 'target': 10, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 5, 'target': 6, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 5, 'target': 10, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 5, 'target': 16, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 6, 'target': 16, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 8, 'target': 30, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 8, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 8, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 9, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 13, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 14, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 14, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 15, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 15, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 18, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 18, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 19, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 20, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 20, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 22, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 22, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 23, 'target': 25, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 23, 'target': 27, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 23, 'target': 29, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 23, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 23, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 24, 'target': 25, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 24, 'target': 27, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 24, 'target': 31, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 25, 'target': 31, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 26, 'target': 29, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 26, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 27, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 28, 'target': 31, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 28, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 29, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 29, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 30, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 30, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 31, 'target': 32, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 31, 'target': 33, 'width': 4.461975483759454, 'weight': 1},
#    {'source': 32, 'target': 33, 'width': 4.461975483759454, 'weight': 1}],
#   'nodes': [{'id': 0,
#     'x': 351.5358795907934,
#     'y': 350.6236152267286,
#     'x_canvas': 281.4579129765498,
#     'y_canvas': 278.2996761134498,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 1,
#     'x': 402.15540742092116,
#     'y': 321.40561264985257,
#     'x_canvas': 456.7014773239314,
#     'y_canvas': 177.14766750788453,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 2,
#     'x': 373.49926984872695,
#     'y': 367.676545557662,
#     'x_canvas': 357.49463158975686,
#     'y_canvas': 337.3365028453993,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 3,
#     'x': 363.1848368428252,
#     'y': 311.7737857253981,
#     'x_canvas': 321.78631739444563,
#     'y_canvas': 143.80251883160895,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 4,
#     'x': 312.26179612945214,
#     'y': 343.3242246559852,
#     'x_canvas': 145.49199888626345,
#     'y_canvas': 253.02936491115133,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 5,
#     'x': 314.9057066811885,
#     'y': 384.13526052658636,
#     'x_canvas': 154.64515239762773,
#     'y_canvas': 394.31617056200025,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 6,
#     'x': 302.7256083445819,
#     'y': 364.82273117290777,
#     'x_canvas': 112.47795056651648,
#     'y_canvas': 327.45666741018,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 7,
#     'x': 366.109461786549,
#     'y': 332.4327561431245,
#     'x_canvas': 331.91129724880875,
#     'y_canvas': 215.3233679374896,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 8,
#     'x': 402.48614725379076,
#     'y': 370.5100134510124,
#     'x_canvas': 457.8464905168287,
#     'y_canvas': 347.145899226198,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 9,
#     'x': 386.797938833851,
#     'y': 387.5438774318154,
#     'x_canvas': 403.5342975828885,
#     'y_canvas': 406.1167187214312,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 10,
#     'x': 323.3626714934237,
#     'y': 363.66953823372694,
#     'x_canvas': 183.92295724460246,
#     'y_canvas': 323.4643417266916,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 11,
#     'x': 333.3776641163697,
#     'y': 338.98684174579495,
#     'x_canvas': 218.59461617527336,
#     'y_canvas': 238.01345161239556,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 12,
#     'x': 341.6140497961615,
#     'y': 317.3757098035572,
#     'x_canvas': 247.1087814734999,
#     'y_canvas': 163.19624265207744,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 13,
#     'x': 384.4151145123341,
#     'y': 347.06368048883115,
#     'x_canvas': 395.2850181996912,
#     'y_canvas': 265.97526932706546,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 14,
#     'x': 428.43324716961195,
#     'y': 384.0930061222585,
#     'x_canvas': 547.6747143000584,
#     'y_canvas': 394.1698868501362,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 15,
#     'x': 412.7627599997109,
#     'y': 423.4902299238283,
#     'x_canvas': 493.423871899294,
#     'y_canvas': 530.5621097793553,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 16,
#     'x': 290.5723404801017,
#     'y': 387.962207522443,
#     'x_canvas': 70.40363517212427,
#     'y_canvas': 407.56496723930286,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 17,
#     'x': 378.1077009692718,
#     'y': 314.25997380275817,
#     'x_canvas': 373.4489071476771,
#     'y_canvas': 152.40964100344445,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 18,
#     'x': 434.7463509716602,
#     'y': 414.1538970612175,
#     'x_canvas': 569.530524889178,
#     'y_canvas': 498.2399543007791,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 19,
#     'x': 397.497261877671,
#     'y': 353.24240653415757,
#     'x_canvas': 440.57509165341617,
#     'y_canvas': 287.3658674168514,
#     'radius': 17.309877418797267,
#     'color': '#37d1f8'},
#    {'id': 20,
#     'x': 442.9480193076649,
#     'y': 403.0905076697315,
#     'x_canvas': 597.9244995943525,
#     'y_canvas': 459.9387714601701,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 21,
#     'x': 380.26070032404647,
#     'y': 327.2560231419618,
#     'x_canvas': 380.90253813045683,
#     'y_canvas': 197.40164520149597,
#     'radius': 17.309877418797267,
#     'color': '#8e4b25'},
#    {'id': 22,
#     'x': 440.1564936935375,
#     'y': 390.0289305468915,
#     'x_canvas': 588.2603063559573,
#     'y_canvas': 414.7199116816646,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 23,
#     'x': 400.8625798963569,
#     'y': 444.47700585603457,
#     'x_canvas': 452.2257401291606,
#     'y_canvas': 603.2178135398065,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 24,
#     'x': 351.9756344277535,
#     'y': 446.12182714322614,
#     'x_canvas': 282.9803334409703,
#     'y_canvas': 608.9121445112291,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 25,
#     'x': 371.1518591534709,
#     'y': 457.251834093443,
#     'x_canvas': 349.3679533124657,
#     'y_canvas': 647.4439557069525,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 26,
#     'x': 436.7356513234979,
#     'y': 428.74946153578526,
#     'x_canvas': 576.4174339370743,
#     'y_canvas': 548.769440683363,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 27,
#     'x': 379.47554495233805,
#     'y': 423.10323567902265,
#     'x_canvas': 378.18434948266054,
#     'y_canvas': 529.2223451914822,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 28,
#     'x': 371.16699249269806,
#     'y': 398.3369758723592,
#     'x_canvas': 349.4203445618575,
#     'y_canvas': 443.4821609163962,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 29,
#     'x': 425.06779093709775,
#     'y': 441.5399444979926,
#     'x_canvas': 536.0235873314289,
#     'y_canvas': 593.0497791239679,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 30,
#     'x': 428.6325820803002,
#     'y': 359.80609361100096,
#     'x_canvas': 548.3648068739185,
#     'y_canvas': 310.08919115995195,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 31,
#     'x': 363.4203706630886,
#     'y': 417.34603522730714,
#     'x_canvas': 322.6017297057938,
#     'y_canvas': 509.2910583725543,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 32,
#     'x': 420.26800735455635,
#     'y': 403.36628306037824,
#     'x_canvas': 519.4068542413193,
#     'y_canvas': 460.8934991016131,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'},
#    {'id': 33,
#     'x': 406.2586446361192,
#     'y': 401.0660148566062,
#     'x_canvas': 470.9067839669963,
#     'y_canvas': 452.93002697408315,
#     'radius': 17.309877418797267,
#     'color': '#79aaa0'}]},
#  {'zoom': 2.230987741879727,
#   'node_charge': -45,
#   'node_gravity': 0.1,
#   'link_distance': 15,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': False,
#   'freeze_nodes': False,
#   'node_fill_color': '#79aaa0',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 5,
#   'node_stroke_width': 1,
#   'node_size_variation': 0.5,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})

# %%
print('Modularity of Louvain-algorithm Grapy:',S)
MG=community_louvain.modularity(GD, G_GD)
print('Modularity of Greedy-algorithm Grapy:',MG)
# Out:
# Modularity of Louvain-algorithm Grapy: 0.4188034188034188
# Modularity of Greedy-algorithm Grapy: 0.3806706114398422

# %% [markdown]
# <font color=blue>Lower.</font>
# + <font color=blue>Different modularity values for different algorithmic partitions.</font>
# + <font color=blue>Better partitions have higher modularity values.</font>

# %% [markdown]
# > 12.  Compare the communities found by the Louvain algorithm with the club split partitioning by creating a matrix **_D_** with dimension (2 times _A_), where _A_ is the number of communities found by Louvain. We set entry _D_(_i_,_j_) to be the number of nodes that community _i_ has in common with group split _j_. The matrix **_D_** is what we call a [**confusion matrix**](https://en.wikipedia.org/wiki/Confusion_matrix). Use the confusion matrix to explain how well the communities you've detected correspond to the club split partitioning.

# %%
n = 2
m = 3
D = [None]*n
for i in range(len(D)):
    D[i] = [0]*m
print(D)
# Out:
# [[0, 0, 0], [0, 0, 0]]

# %%
GX = nx.karate_club_graph()
GXN= nw.get_filtered_network(G_0,node_group_key='club')
nw.visualize(GXN)
# Out:
# ({'xlim': [0, 760],
#   'ylim': [0, 760],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 2.195026565101178,
#   'links': [{'source': 0,
#     'target': 1,
#     'width': 4.390053130202356,
#     'weight': 1},
#    {'source': 0, 'target': 2, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 3, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 4, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 5, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 6, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 7, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 8, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 10, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 11, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 12, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 13, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 17, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 19, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 21, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 0, 'target': 31, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 2, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 3, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 7, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 13, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 17, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 19, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 21, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 1, 'target': 30, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 3, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 7, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 8, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 9, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 13, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 27, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 28, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 2, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 3, 'target': 7, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 3, 'target': 12, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 3, 'target': 13, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 4, 'target': 6, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 4, 'target': 10, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 5, 'target': 6, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 5, 'target': 10, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 5, 'target': 16, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 6, 'target': 16, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 8, 'target': 30, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 8, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 8, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 9, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 13, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 14, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 14, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 15, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 15, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 18, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 18, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 19, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 20, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 20, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 22, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 22, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 23, 'target': 25, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 23, 'target': 27, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 23, 'target': 29, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 23, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 23, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 24, 'target': 25, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 24, 'target': 27, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 24, 'target': 31, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 25, 'target': 31, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 26, 'target': 29, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 26, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 27, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 28, 'target': 31, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 28, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 29, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 29, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 30, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 30, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 31, 'target': 32, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 31, 'target': 33, 'width': 4.390053130202356, 'weight': 1},
#    {'source': 32, 'target': 33, 'width': 4.390053130202356, 'weight': 1}],
#   'nodes': [{'id': 0,
#     'x': 345.28779878924416,
#     'y': 358.1279461129465,
#     'x_canvas': 262.32379362926326,
#     'y_canvas': 305.8525752562398,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 1,
#     'x': 389.7241222373064,
#     'y': 318.44680278572326,
#     'x_canvas': 412.96529102905083,
#     'y_canvas': 171.33139110977822,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 2,
#     'x': 371.31197447874484,
#     'y': 369.0767005473542,
#     'x_canvas': 350.54713188639107,
#     'y_canvas': 342.96943449842047,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 3,
#     'x': 348.7295963188612,
#     'y': 316.0148511908095,
#     'x_canvas': 273.9916701180641,
#     'y_canvas': 163.08694599294017,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 4,
#     'x': 304.61714151991686,
#     'y': 358.67681585468114,
#     'x_canvas': 124.448104645993,
#     'y_canvas': 307.7132728422805,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 5,
#     'x': 316.6548088889031,
#     'y': 397.62975352503435,
#     'x_canvas': 165.2564365905596,
#     'y_canvas': 439.7658011222386,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 6,
#     'x': 299.5467514529746,
#     'y': 381.2207325611432,
#     'x_canvas': 107.2592129282084,
#     'y_canvas': 384.13834824004357,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 7,
#     'x': 356.2542648287827,
#     'y': 336.1132673859487,
#     'x_canvas': 299.5006961538586,
#     'y_canvas': 231.22164472738154,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 8,
#     'x': 398.35651727149406,
#     'y': 367.63052647244433,
#     'x_canvas': 442.229568835842,
#     'y_canvas': 338.06682754895473,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 9,
#     'x': 387.9171063937196,
#     'y': 386.7180211946593,
#     'x_canvas': 406.83941131217443,
#     'y_canvas': 402.7744487797206,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 10,
#     'x': 320.095146293434,
#     'y': 376.2442947614846,
#     'x_canvas': 176.91936317774162,
#     'y_canvas': 367.26795970005355,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 11,
#     'x': 325.2934817763534,
#     'y': 350.27479547896087,
#     'x_canvas': 194.5419966534546,
#     'y_canvas': 279.2299773675461,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 12,
#     'x': 328.5467865004951,
#     'y': 327.35169684115954,
#     'x_canvas': 205.5708725170332,
#     'y_canvas': 201.51945507653022,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 13,
#     'x': 377.4514832134426,
#     'y': 346.0684802928497,
#     'x_canvas': 371.3603926903579,
#     'y_canvas': 264.97034540425216,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 14,
#     'x': 427.46100671878764,
#     'y': 374.8862573951836,
#     'x_canvas': 540.8953343895812,
#     'y_canvas': 362.6641408754929,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 15,
#     'x': 423.2442959198021,
#     'y': 416.0163203992404,
#     'x_canvas': 526.6004607463221,
#     'y_canvas': 502.097239707816,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 16,
#     'x': 293.6315456096561,
#     'y': 406.5866165868614,
#     'x_canvas': 87.20635084327512,
#     'y_canvas': 470.13004278177937,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 17,
#     'x': 363.8867295953205,
#     'y': 316.8835711128773,
#     'x_canvas': 325.3751572268193,
#     'y_canvas': 166.03195268401532,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 18,
#     'x': 445.4745589493415,
#     'y': 399.55104347572,
#     'x_canvas': 601.962233514834,
#     'y_canvas': 446.27907613358684,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 19,
#     'x': 391.78746833462515,
#     'y': 350.12029755468717,
#     'x_canvas': 419.96014392495704,
#     'y_canvas': 278.7062211957523,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 20,
#     'x': 447.0770007958032,
#     'y': 386.5952959088945,
#     'x_canvas': 607.3945965123987,
#     'y_canvas': 402.3584035405586,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 21,
#     'x': 369.04729663907665,
#     'y': 328.772315348893,
#     'x_canvas': 342.8697536871239,
#     'y_canvas': 206.3354272954955,
#     'radius': 16.950265651011783,
#     'color': '#79aaa0'},
#    {'id': 22,
#     'x': 440.6580310267692,
#     'y': 375.1412940149252,
#     'x_canvas': 585.6339479542105,
#     'y_canvas': 363.52872856656427,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 23,
#     'x': 414.2854533614359,
#     'y': 439.1203444294359,
#     'x_canvas': 496.2295084883426,
#     'y_canvas': 580.4211086916505,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 24,
#     'x': 365.5748633183745,
#     'y': 449.4788815480968,
#     'x_canvas': 331.0980202388587,
#     'y_canvas': 615.5370998750843,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 25,
#     'x': 386.72785820513815,
#     'y': 456.69079748277255,
#     'x_canvas': 402.8077967678862,
#     'y_canvas': 639.9858780641882,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 26,
#     'x': 445.13237803406906,
#     'y': 415.6933464124903,
#     'x_canvas': 600.8022220319192,
#     'y_canvas': 501.00234073306,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 27,
#     'x': 389.2961027651274,
#     'y': 421.7549906385616,
#     'x_canvas': 411.5142822776029,
#     'y_canvas': 521.5516367158259,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 28,
#     'x': 376.2706970288138,
#     'y': 400.13187833994056,
#     'x_canvas': 367.3574647890573,
#     'y_canvas': 448.2481371831684,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 29,
#     'x': 437.90090210640943,
#     'y': 431.98624731114336,
#     'x_canvas': 576.2871344273735,
#     'y_canvas': 556.2361404246153,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 30,
#     'x': 422.71214191679366,
#     'y': 350.65975063106214,
#     'x_canvas': 524.7964304026736,
#     'y_canvas': 280.53499578591436,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 31,
#     'x': 372.3409542881424,
#     'y': 419.85527964097554,
#     'x_canvas': 354.03542811015427,
#     'y_canvas': 515.1115155019793,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 32,
#     'x': 426.37632763391315,
#     'y': 396.1898235275041,
#     'x_canvas': 537.2182146626374,
#     'y_canvas': 434.8843619268389,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'},
#    {'id': 33,
#     'x': 411.150830538055,
#     'y': 394.3656937922145,
#     'x_canvas': 485.60297057393655,
#     'y_canvas': 428.7004652078251,
#     'radius': 16.950265651011783,
#     'color': '#a994a5'}]},
#  {'zoom': 2.195026565101178,
#   'node_charge': -45,
#   'node_gravity': 0.1,
#   'link_distance': 15,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': False,
#   'freeze_nodes': False,
#   'node_fill_color': '#79aaa0',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 5,
#   'node_stroke_width': 1,
#   'node_size_variation': 0.5,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})

# %%
G["club"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ASTR01~1\AppData\Local\Temp/ipykernel_520/2228319390.py in <module>
# ----> 1 G["club"]
#
# c:\users\astr010gos\appdata\local\programs\python\python39\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     474         AtlasView({1: {}})
#     475         """
# --> 476         return self.adj[n]
#     477
#     478     def add_node(self, node_for_adding, **attr):
#
# c:\users\astr010gos\appdata\local\programs\python\python39\lib\site-packages\networkx\classes\coreviews.py in __getitem__(self, name)
#      80
#      81     def __getitem__(self, name):
# ---> 82         return AtlasView(self._atlas[name])
#      83
#      84     def copy(self):
#
# KeyError: 'club'

# %% [markdown]
# _Exercise: Community detection on the GME network._
# > * Consider the GME network you built in [Week 4](https://github.com/lalessan/comsocsci2022/blob/main/lectures/Week4.ipynb), part 2.
# > * Use [the Python Louvain-algorithm implementation](https://anaconda.org/auto/python-louvain) to find communities. How many communities do you find? What are their sizes? Report the value of modularity found by the algorithm. Is the modularity significantly different than 0?
# > * Visualize the network, using netwulf (see Week 4). This time assign each node a different color based on their _community_. Describe the structure you observe.

# %%
# Out:
# [[0, 0, 0], [0, 0, 0]]

# %%
def double_edge_swap(G, nswap=1, max_tries=100, seed=None):
    if G.is_directed():
        raise nx.NetworkXError("double_edge_swap() not defined for directed graphs.")
    if nswap > max_tries:
        raise nx.NetworkXError("Number of swaps > number of tries allowed.")
    if len(G) < 4:
        raise nx.NetworkXError("Graph has less than four nodes.")
    # Instead of choosing uniformly at random from a generated edge list,
    # this algorithm chooses nonuniformly from the set of nodes with
    # probability weighted by degree.
    n = 0
    swapcount = 0
    keys, degrees = zip(*G.degree())  # keys, degree
    cdf = nx.utils.cumulative_distribution(degrees)  # cdf of degree
    discrete_sequence = nx.utils.discrete_sequence
    while swapcount < nswap:
        #        if random.random() < 0.5: continue # trick to avoid periodicities?
        # pick two random edges without creating edge list
        # choose source node indices from discrete distribution
        (ui, xi) = discrete_sequence(2, cdistribution=cdf, seed=seed)
        if ui == xi:
            continue  # same source, skip
        u = keys[ui]  # convert index to label
        x = keys[xi]
        # choose target uniformly from neighbors
        v = seed.choice(list(G[u]))
        y = seed.choice(list(G[x]))
        if v == y:
            continue  # same target, skip
        if (x not in G[u]) and (y not in G[v]):  # don't create parallel edges
            G.add_edge(u, x)
            G.add_edge(v, y)
            G.remove_edge(u, v)
            G.remove_edge(x, y)
            swapcount += 1
        if n >= max_tries:
            e = (
                f"Maximum number of swap attempts ({n}) exceeded "
                f"before desired swaps achieved ({nswap})."
            )
            raise nx.NetworkXAlgorithmError(e)
        n += 1
    return G

# %%
import networkx as nx
import netwulf as nw
from networkx.algorithms import community
import community as community_louvain
#Configuration Model Using Zachary's Karate Club Graph
#Instantiate the original graph

G = nx.karate_club_graph()

#Get the original graph's degree sequence
# Extracts Degree Sequence
DegreeSequence = list(nx.degree(G).values())

# Convention: Non-increasing order
DegreeSequence.sort(reverse=True)

# print Degree Sequence
print(DegreeSequence) 
 

#Use the original graph's degree sequence to build the configuration model
G2 = nx.configuration_model(DegreeSequence,create_using=None,seed=None)

#Remove any self loops
G2.remove_edges_from(G2.selfloop_edges())

#Get new degree sequence to compare to original degree sequence

DegreeSequence2 = list(nx.degree(G2).values())
DegreeSequence2.sort(reverse=True)

print(DegreeSequence2) 
 
#Draw the Original Graph
#Make a blank figure
f1=plt.figure()

#Fill the figure

nx.draw_networkx(G,pos=nx.spring_layout(G))
limits=plt.axis('off')
plt.show()
plt.title("Original Zachary's Karate Club") 
 
 

#Draw the New Graph

f2 = plt.figure()

nx.draw_networkx(G2,pos=nx.spring_layout(G))

limits=plt.axis('off')

plt.show()

plt.title("Zachary's Karate Club: Configuration Model")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ASTR01~1\AppData\Local\Temp/ipykernel_14188/1244385442.py in <module>
#      10 #Get the original graph's degree sequence
#      11 # Extracts Degree Sequence
# ---> 12 DegreeSequence = list(nx.degree(G).values())
#      13
#      14 # Convention: Non-increasing order
#
# AttributeError: 'DegreeView' object has no attribute 'values'
